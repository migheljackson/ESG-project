# %%
# Dependencies
import pandas as pd
import pymongo

# %%
International_ESG_df = pd.read_csv('final_merged_csv.csv')

# %%
International_ESG_df.head()
# Out:
#      Country  EPI 2000  EPI 2002  EPI 2004  EPI 2006  EPI 2008  EPI 2010  \
# 0    Albania     58.98     61.43     64.54     66.62     67.46     71.42
# 1    Algeria     46.81     47.51     48.17     48.93     49.79     67.41
# 2     Angola     42.79     43.72     45.15     47.51     48.47     36.35
# 3  Argentina     51.73     53.01     53.12     55.20     56.07     61.05
# 4    Armenia     44.61     46.23     46.64     46.65     46.46     60.44
#
#    EPI 2012  EPI 2014  EPI 2016  ...        2016        2017        2018  \
# 0     65.85     54.73     74.38  ...   2876101.0   2873457.0   2866376.0
# 1     48.56     50.08     70.28  ...  40551398.0  41389174.0  42228415.0
# 2     47.57     28.69     51.32  ...  28842482.0  29816769.0  30809787.0
# 3     56.48     49.55     79.84  ...  43590368.0  44044811.0  44494502.0
# 4     47.48     61.67     81.60  ...   2936147.0   2944789.0   2951741.0
#
#          2019        2020  Continent_Name  Continent_Code  \
# 0   2854191.0   2837743.0          Europe              EU
# 1  43053054.0  43851043.0          Africa              AF
# 2  31825299.0  32866268.0          Africa              AF
# 3  44938712.0  45376763.0   South America              SA
# 4   2957728.0   2963234.0          Europe              EU
#
#                                Country_Name  Two_Letter_Country_Code  \
# 0                      Albania, Republic of                       AL
# 1  Algeria, People's Democratic Republic of                       DZ
# 2                       Angola, Republic of                       AO
# 3             Argentina, Argentine Republic                       AR
# 4                      Armenia, Republic of                       AM
#
#    Country_Number
# 0               8
# 1              12
# 2              24
# 3              32
# 4              51
#
# [5 rows x 157 columns]

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb+srv://SteveD:tYzociCA7OZ1bYmu@cluster0.eouih.mongodb.net/myFirstDatabase?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
ESGdb = client.International_ESG_df

# %%
#Load df into a MongoDB collection
collection = ESGdb.ESG
# Insert collection
#collection.insert_many

# %%
#for index, row in df.iterrows():
    #print(row['Country'], row['c2'])

# %%
collection.insert_many(International_ESG_df.to_dict('records'))
