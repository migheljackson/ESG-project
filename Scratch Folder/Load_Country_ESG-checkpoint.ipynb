# %%
# Dependencies
import pandas as pd
import pymongo
import numpy as np

# %%
country_esg_df = pd.read_csv('CountryESG82021.csv')
gsir_df = pd.read_csv('GSIR_Report_Data - Sheet1.csv')

# %%
for columns in gsir_df.columns:
    print(columns)
# Out:
# gsia_region
# ici_2020
# pos_bic_2020
# sustainability_2020
# norms_based_2020
# cesa_2020
# neg_ex_2020
# esg_int_2020
# esg_tot_2020
# ici_2018
# pos_bic_2018
# sustainability_2018
# norms_based_2018
# cesa_2018
# neg_ex_2018
# esg_int_2018
# esg_tot_2018
# neg_ex_2016
# esg_int_2016
# cesa_2016
# norms_based_2016
# pos_bic_2016
# sustainability_2016
# ici_2016
# esg_tot_2016
# neg_ex_2014
# esg_int_2014
# cesa_2014
# norms_based_2014
# pos_bic_2014
# sustainability_2014
# ici_2014
# esg_tot_2014
# neg_ex_2012
# esg_int_2012
# cesa_2012
# norms_based_2012
# pos_bic_2012
# sustainability_2012
# ici_2012
# esg_tot_2012

# %%
gsir_df
# Out:
#                 gsia_region  ici_2020  pos_bic_2020  sustainability_2020  \
# 0                    Europe    111.15        597.87               152.10
# 1  United States of America    212.00        658.00              1688.00
# 2                    Canada     15.60         16.38                37.44
# 3                   Oceania     17.75          2.84                 3.55
# 4                     Japan      1.27        133.25                72.70
# 5                    Global    352.00       1384.00              1948.00
#
#    norms_based_2020  cesa_2020  neg_ex_2020  esg_int_2020  esg_tot_2020  \
# 0           3211.65    4956.12      9656.01       4325.49      12554.10
# 1              0.00    1980.00      3404.00      16059.00      17081.00
# 2            819.00    2084.94      1061.58       2346.24       2469.48
# 3              0.00       0.00        90.17        805.85        919.45
# 4            257.60    1703.25      1230.89       1865.12       2821.35
# ...

# %%
for columns in country_esg_df.columns:
    print(columns)
# Out:
# Country
# EPI 2000
# EPI 2002
# EPI 2004
# EPI 2006
# EPI 2008
# EPI 2010
# EPI 2012
# EPI 2014
# EPI 2016
# EPI 2018
# EPI 2020
# CCPI 2008
# CCPI 2009
# CCPI 2010
# CCPI 2011
# CCPI 2012
# CCPI 2013
# CCPI 2014
# CCPI 2015
# CCPI 2016
# CCPI 2017
# CCPI 2018
# CCPI 2019
# CCPI 2020
# 2014 Sustainable Competitiveness
# 2015 Sustainable Competitiveness
# 2016 Sustainable Competitiveness
# 2017 Sustainable Competitiveness
# 2018 Sustainable Competitiveness
# 2019 Sustainable Competitiveness
# 2020 Sustainable Competitiveness
# 2014 Natural capital
# 2015 Natural capital
# 2016 Natural capital
# 2017 Natural capital
# 2018 Natural capital
# 2019 Natural capital
# 2020 Natural capital
# 2014 Resource Intensity
# 2015 Resource Intensity
# 2016 Resource Intensity
# 2017 Resource Intensity
# 2018 Resource Intensity
# 2019 Resource Intensity
# 2020 Resource Intensity
# 2014 Social capital
# 2015 Social capital
# 2016 Social capital
# 2017 Social capital
# 2018 Social capital
# ...

# %%
country_esg_gsir_df=country_esg_df.merge(gsir_df,how='left',on='gsia_region')

# %%
for columns in country_esg_gsir_df.columns:
    print(columns)
# Out:
# Country
# EPI 2000
# EPI 2002
# EPI 2004
# EPI 2006
# EPI 2008
# EPI 2010
# EPI 2012
# EPI 2014
# EPI 2016
# EPI 2018
# EPI 2020
# CCPI 2008
# CCPI 2009
# CCPI 2010
# CCPI 2011
# CCPI 2012
# CCPI 2013
# CCPI 2014
# CCPI 2015
# CCPI 2016
# CCPI 2017
# CCPI 2018
# CCPI 2019
# CCPI 2020
# 2014 Sustainable Competitiveness
# 2015 Sustainable Competitiveness
# 2016 Sustainable Competitiveness
# 2017 Sustainable Competitiveness
# 2018 Sustainable Competitiveness
# 2019 Sustainable Competitiveness
# 2020 Sustainable Competitiveness
# 2014 Natural capital
# 2015 Natural capital
# 2016 Natural capital
# 2017 Natural capital
# 2018 Natural capital
# 2019 Natural capital
# 2020 Natural capital
# 2014 Resource Intensity
# 2015 Resource Intensity
# 2016 Resource Intensity
# 2017 Resource Intensity
# 2018 Resource Intensity
# 2019 Resource Intensity
# 2020 Resource Intensity
# 2014 Social capital
# 2015 Social capital
# 2016 Social capital
# 2017 Social capital
# 2018 Social capital
# ...

# %%
country_esg_gsir_df=country_esg_gsir_df.fillna("null")

# %%
print(country_esg_gsir_df['CCPI 2008'])
# Out:
# 0      null
# 1      50.5
# 2      null
# 3      58.5
# 4      null
#        ...
# 112    null
# 113    null
# 114    null
# 115    null
# 116    null
# Name: CCPI 2008, Length: 117, dtype: object

# %%
country_esg_gsir_df['CCPI 2008'].fillna("null")
# Out:
# 0      null
# 1      50.5
# 2      null
# 3      58.5
# 4      null
#        ...
# 112    null
# 113    null
# 114    null
# 115    null
# 116    null
# Name: CCPI 2008, Length: 117, dtype: object

# %%
country_esg_gsir_df['CCPI 2008'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Name: CCPI 2008, Length: 117, dtype: bool

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb+srv://admin:admin@cluster0.5lstl.mongodb.net/myFirstDatabase?authSource=admin&replicaSet=atlas-efjkbc-shard-0&w=majority&readPreference=primary&appname=MongoDB%20Compass&retryWrites=true&ssl=true'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.International_ESG_df
db.ESG.drop()

# %%
#Load df into a MongoDB collection
collection = db.ESG
# Insert collection
#collection.insert_many

# %%
#for index, row in df.iterrows():
    #print(row['Country'], row['c2'])

# %%
collection.insert_many(country_esg_gsir_df.to_dict('records'))
